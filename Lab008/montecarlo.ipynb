# %% [markdown]
# <a href="https://colab.research.google.com/github/NoheliaEstefhania/FC_Lab_2023/blob/main/Lab008/montecarlo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !jupyter nbconvert --to html /content/Lab008_montecarlo.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/Lab008_montecarlo.ipynb to html
# [NbConvertApp] Writing 802978 bytes to /content/Lab008_montecarlo.html

# %%
import numpy as np #importa numpy para algunas operacione matemáticas
import matplotlib.pyplot as plt  #importa matplotlib para las gráficas
from numpy.random import uniform #importa numpy.random para generar los números aleatorios

# %%
'''
a: límite inferior
b: límite superior
n_itera: número de iteraciones
x_: arreglo de números aleatorios generados
funcion: función de integración
'''

# %%
#Gráfica de las funciones montecarlo
def grafica (c, f, muestreo):
  plt.title('ÁREAS POR EL MÉTODO MONTECARLO')
  plt.xlabel('X')
  plt.ylabel('Y')
  plt.plot(c, f)
  plt.hist(muestreo, density=True)
  plt.show()

# %%
#Método que resuelve integrales con el método montecarlo
def montecarlo (funcion, a, b, n_itera):
  amplitud = b - a #calcula la amplitud del rango
  x_ = np.random.uniform(a, b, n_itera) #genera un muestreo aleatorio en el rango definido
  cont = evaluaFuncion(x_, amplitud, n_itera)
  resultado = (amplitud) * cont / n_itera #calcula el resultado final multiplicando la amplitud por la suma y dividiendo por el número de iteraciones
  print('Resultado : ', resultado, '\n')
  grafica(x, funcion, x_) #grafíca

# %% [markdown]
# ### **Aplicando la integración por método Monte Carlo resuelva las siguientes integrales:**

# %% [markdown]
# ### **1. Calcule:** $$\int _0^1\:e^{x^2}dx$$

# %%
def evaluaFuncion (x_, amplitud, n_itera):
  cont = 0 #inicializamos cont en cero
  for k in range(n_itera): #itera sobre los elementos del muestreo y realiza el cálculo de la cont
    cont = cont + np.exp(x_[k]**2) #función
  return cont

# %%
a = 0
b = 1
x = np.linspace(0.0001, b)
funcion = np.exp(x**2)
n_itera = 1000
montecarlo (funcion, a, b, n_itera)
# Out:
# Resultado :  1.459298455795726

# %% [markdown]
# **2. Calcule:** $$\int _{-1}^1\:e^{x^{\:}}4dx$$

# %%
def evaluaFuncion (x_, amplitud, n_itera):
  cont = 0 #inicializamos cont en cero
  for k in range(n_itera): #itera sobre los elementos del muestreo y realiza el cálculo de la cont
    cont = cont + np.exp(x_[k])*4
  return cont

# %%
a = -1
b = 1
x = np.linspace(-1.0001, b)
funcion = np.exp(x)*4
n_itera = 1000
montecarlo (funcion, a, b, n_itera)
# Out:
# Resultado :  9.23998971625102

# %% [markdown]
# **3. Calcule:** $$\int _0^1\:\left(1-e^{x^{\:2}}\right)^{\frac{1}{2}}dx$$

# %%
def evaluaFuncion (x_, amplitud, n_itera):
  cont = 0 #inicializamos cont en cero
  for k in range(n_itera): #itera sobre los elementos del muestreo y realiza el cálculo de la cont
    cont = cont + np.sqrt(1-(np.exp(x_[k]**2)))
  return cont

# %%
a = 0
b = 1
x = np.linspace(0.0001, b)
funcion = np.sqrt(1-(np.exp(x**2)))
n_itera = 1000
montecarlo (funcion, a, b, n_itera)
# Out:
# <ipython-input-150-b5588127df0b>:4: RuntimeWarning: invalid value encountered in sqrt
#   funcion = np.sqrt(1-(np.exp(x**2)))
# Resultado :  nan

# %% [markdown]
# **4. Calcule:** $$\int _0^{\infty }\:x\left(1+x^2\right)^{-2}dx$$

# %%
def evaluaFuncion (x_, amplitud, n_itera):
  cont = 0 #inicializamos cont en cero
  for k in range(n_itera): #itera sobre los elementos del muestreo y realiza el cálculo de la cont
    cont = cont + (x_[k]*(1 + x_[k]**2)**(-2))
  return cont

# %%
a = 0
b = 10000 # ∞
x = np.linspace(0.0001, b)
funcion = x*(1 + x**2)**(-2)
n_itera = 1000000
montecarlo (funcion, a, b, n_itera)
# Out:
# Resultado :  0.5235823081155045

# %% [markdown]
# **5. Calcule:** $$\int _0^1\:e^{x\:+x^2}dx$$

# %%
def evaluaFuncion (x_, amplitud, n_itera):
  cont = 0 #inicializamos cont en cero
  for k in range(n_itera): #itera sobre los elementos del muestreo y realiza el cálculo de la cont
    cont = cont + np.exp(x_[k] + x_[k]**2)
  return cont

# %%
a = 0
b = 1
x = np.linspace(0.0001, b)
funcion = np.exp(x + x**2)
n_itera = 1000000
montecarlo (funcion, a, b, n_itera)
# Out:
# Resultado :  2.7388693677352176

# %% [markdown]
# **6. Calcule:** $$\int _0^{\infty }\:e^{-x}dx$$

# %%
def evaluaFuncion (x_, amplitud, n_itera):
  cont = 0 #inicializamos cont en cero
  for k in range(n_itera): #itera sobre los elementos del muestreo y realiza el cálculo de la cont
    cont = cont + np.exp(-x_[k])
  return cont

# %%
a = 0
b = 10
x = np.linspace(0.0001, b)
funcion = np.exp(-x)
n_itera = 100000
montecarlo (funcion, a, b, n_itera)
# Out:
# Resultado :  0.9965109087174959

# %% [markdown]
# **7. Calcule:** $$\int _0^{\infty }\:x\left(1+x^2\right)^{\frac{3}{2}}dx$$

# %%
def evaluaFuncion (x_, amplitud, n_itera):
  cont = 0 #inicializamos cont en cero
  for k in range(n_itera): #itera sobre los elementos del muestreo y realiza el cálculo de la cont
    cont = cont + (x_[k] * (1 + x_[k]**2)**(3/2))
  return cont

# %%
a = 0
b = 1000000000000
x = np.linspace(0.0001, b)
funcion = x * (1 + x**2)**(3/2)
n_itera = 1000000
montecarlo (funcion, a, b, n_itera)
# Out:
# Resultado :  0.0
